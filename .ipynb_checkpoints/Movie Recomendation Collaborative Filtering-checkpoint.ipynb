# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

plt.rcParams['figure.figsize'] = (6, 4)
plt.style.use('ggplot')
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
movies = pd.read_csv('dataset/movies.csv')
display(movies.head(3))
print('Shape:', movies.shape)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# Shape: (9742, 3)

# %%
movies = movies[movies.genres != '(no genres listed)']
display(movies.head(3))
print('Shape:', movies.shape)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# Shape: (9708, 3)

# %%
ratings = pd.read_csv('dataset/ratings.csv')
display(ratings.head(3))
print('Shape:', ratings.shape)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# Shape: (100836, 4)

# %%
print(len(ratings["userId"].unique()))
print(len(ratings["movieId"].unique()))
# Out:
# 610
# 9724

# %%
# merge 2 dataset
mergedata = pd.merge(movies, ratings, on= ['movieId', 'movieId'])
display(mergedata.head(3))
print('Shape:', mergedata.shape)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# Shape: (100789, 6)

# %%
print(len(mergedata["userId"].unique()))
print(len(mergedata["movieId"].unique()))
# Out:
# 610
# 9690

# %%
mergedata.isna().sum()
# Out:
# movieId      0
# title        0
# genres       0
# userId       0
# rating       0
# timestamp    0
# dtype: int64

# %%
movies_ratings = pd.crosstab(mergedata['userId'], mergedata['title'])
display(movies_ratings.head(3))
print('Shape:', movies_ratings.shape)
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1                0                                        0
# 2                0                                        0
# 3                0                                        0
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                            0                    0
# 2                            0                    0
# 3                            0                    0
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                               0                                0
# 2                               0                                0
# 3                               0                                0
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                        0                     0                            0
# 2                        0                     0                            0
# 3                        0                     0                            0
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 1                                    0  ...            0             0
# 2                                    0  ...            0             0
# 3                                    0  ...            0             0
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                   0                        0
# 2                   0                        0
# 3                   0                        0
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                       0
# 2                                                       0
# 3                                                       0
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                     0           0                               0
# 2                     0           0                               0
# 3                     0           0                               0
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                           1                                          0
# 2                           0                                          0
# 3                           0                                          0
#
# [3 rows x 9685 columns]
# Shape: (610, 9685)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 3)
pca.fit(movies_ratings)
pca_samples = pca.transform(movies_ratings)

# %%
ps = pd.DataFrame(pca_samples)
display(ps.head(3))
print('Shape:', ps.shape)
# Out:
#           0         1         2
# 0  2.592215  3.112741  0.357780
# 1 -2.936130 -1.163763  0.345716
# 2 -3.025807  0.079590  0.306964
# Shape: (610, 3)

# %%
tocluster = pd.DataFrame(ps[[0, 1, 2]])

# %%
plt.rcParams['figure.figsize'] = (16, 9)

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(tocluster[0], tocluster[2], tocluster[1])

plt.title('Data points in 3D PCA axis', fontsize=20)
plt.show()

# %%
import time
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist

scores, distortions = [None] * 8, [None] * 8
scores[0], scores[1], scores[2], distortions[0], distortions[1], distortions[2] = 0, 0, 0, 0, 0, 0

for i in range(3, 8):
    start = time.time()
    
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(tocluster)
    scores[i] = silhouette_score(tocluster, kmeans.labels_)
    distortions[i] = sum(np.min(cdist(tocluster, kmeans.cluster_centers_,
                                        'euclidean'), axis = 1)) / tocluster.shape[0]
    
    time.sleep(1)
    end = time.time()
    print('Komputasi:', round((end - start), 5))
# Out:
# Komputasi: 1.1033
# Komputasi: 1.0599
# Komputasi: 1.04256
# Komputasi: 1.04729
# Komputasi: 1.06245

# %%
print('Silhouette Coefficient', scores)
print('Elbow', distortions)
# Out:
# Silhouette Coefficient [0, 0, 0, 0.5100207315257177, 0.5123960104381359, 0.4041716264674119, 0.416853077952186, 0.42681468146690527]
# Elbow [0, 0, 0, 2.763698115352031, 2.588806711093239, 2.2396474279906875, 2.033752405945405, 1.9339223232561704]

# %%
plt.plot(range(0 ,8), scores, '-o')
plt.xlabel('Number of cluster')
plt.ylabel('Score')
plt.title('Silhouette Score') 
plt.show()

# %%
plt.plot(range(0, 8), distortions, '-o')
plt.xlabel('Number of cluster')
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()

# %%
#best_k = scores.index(max(scores))
best_k = 3
best_k
# Out:
# 3

# %%
from sklearn.cluster import KMeans

clusterer = KMeans(n_clusters = best_k, random_state = 0).fit(tocluster)
centers = clusterer.cluster_centers_
c_preds = clusterer.predict(tocluster)

centers
# Out:
# array([[-1.8514473 ,  0.03298232, -0.12039299],
#        [16.9001041 , -0.54669531, -1.34372435],
#        [ 4.74414123, -0.02727936,  0.8776621 ]])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(tocluster[0], tocluster[2], tocluster[1], c = c_preds)
plt.title('Data points in 3D PCA axis', fontsize=20)

plt.show()

# %%
fig = plt.figure(figsize = (10, 8))
plt.scatter(tocluster[1], tocluster[0], c = c_preds)
for ci,c in enumerate(centers):
    plt.plot(c[1], c[0], 'o', markersize = 8, color = 'red', alpha = 1)

plt.xlabel('x_values')
plt.ylabel('y_values')

plt.title('Data points in 2D PCA axis', fontsize = 20)
plt.show()

# %%
movies_ratings['cluster'] = c_preds
display(movies_ratings.head(3))
print('Shape:', movies_ratings.shape)
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1                0                                        0
# 2                0                                        0
# 3                0                                        0
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                            0                    0
# 2                            0                    0
# 3                            0                    0
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                               0                                0
# 2                               0                                0
# 3                               0                                0
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                        0                     0                            0
# 2                        0                     0                            0
# 3                        0                     0                            0
#
# title   *batteries not included (1987)  ...  [REC] (2007)  [REC]² (2009)  \
# userId                                  ...
# 1                                    0  ...             0              0
# 2                                    0  ...             0              0
# 3                                    0  ...             0              0
#
# title   [REC]³ 3 Génesis (2012)  \
# userId
# 1                             0
# 2                             0
# 3                             0
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                       0
# 2                                                       0
# 3                                                       0
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                     0           0                               0
# 2                     0           0                               0
# 3                     0           0                               0
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)  \
# userId
# 1                           1                                          0
# 2                           0                                          0
# 3                           0                                          0
#
# title   cluster
# userId
# 1             2
# 2             0
# 3             0
#
# [3 rows x 9686 columns]
# Shape: (610, 9686)

# %%
movies_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 1 to 610
# Columns: 9686 entries, '71 (2014) to cluster
# dtypes: int32(1), int64(9685)
# memory usage: 45.1 MB

# %%
cluster = list()
for i in range(best_k):
    cluster.append(movies_ratings[movies_ratings['cluster'] == i].drop('cluster', axis = 1).mean())

# %%
cluster[0].sort_values(ascending = False)[0:15]
# Out:
# title
# Shawshank Redemption, The (1994)             0.455487
# Forrest Gump (1994)                          0.436853
# Pulp Fiction (1994)                          0.420290
# Silence of the Lambs, The (1991)             0.378882
# Matrix, The (1999)                           0.337474
# Braveheart (1995)                            0.320911
# Schindler's List (1993)                      0.304348
# Jurassic Park (1993)                         0.293996
# Star Wars: Episode IV - A New Hope (1977)    0.293996
# Apollo 13 (1995)                             0.285714
# Terminator 2: Judgment Day (1991)            0.279503
# Toy Story (1995)                             0.256729
# Usual Suspects, The (1995)                   0.248447
# Fugitive, The (1993)                         0.248447
# Fight Club (1999)                            0.246377
# dtype: float64

# %%
def createMovieInfoList(movielist):
    genre_list = list()
    for x in movies['title']:
        if x in movielist:
            for y in movies[movies['title'] == x].genres.values:
                 genre_list.append(y)
    return genre_list

# %%
def count_word(df, ref_col, liste):
    keyword_count = dict()
    for s in liste: keyword_count[s] = 0
    for liste_keywords in df[ref_col].str.split('|'):        
        if type(liste_keywords) == float and pd.isnull(liste_keywords): continue        
        for s in [s for s in liste_keywords if s in liste]: 
            if pd.notnull(s): keyword_count[s] += 1
    #______________________________________________________________________
    # convert the dictionary in a list to sort the keywords by frequency
    keyword_occurences = []
    for k,v in keyword_count.items():
        keyword_occurences.append([k,v])
    keyword_occurences.sort(key = lambda x:x[1], reverse = True)
    return keyword_occurences, keyword_count

# %%
movielist = list(cluster[0].index)
data = pd.DataFrame()
data['genres'] = createMovieInfoList(movielist)

# %%
set_keywords = set()
for liste_keywords in data['genres'].str.split('|').values:
    if isinstance(liste_keywords, float): continue  # only happen if liste_keywords = NaN
    set_keywords = set_keywords.union(liste_keywords)

# %%
from wordcloud import WordCloud

def makeCloud(Dict,name,color):
    words = dict()

    for s in Dict:
        words[s[0]] = s[1]

        wordcloud = WordCloud(
                      width=1500,
                      height=500, 
                      background_color=color, 
                      max_words=20,
                      max_font_size=500, 
                      normalize_plurals=False)
        wordcloud.generate_from_frequencies(words)


    fig = plt.figure(figsize=(12, 8))
    plt.title(name)
    plt.imshow(wordcloud)
    plt.axis('off')

    plt.show()

# %%
favorite_genre = list()
for i in range(best_k):
    movielist = list(cluster[i].sort_values(ascending = False)[0:15].index)
    data = pd.DataFrame()

    data['genres'] = createMovieInfoList(movielist)
    keyword_occurences, dum = count_word(data, 'genres', set_keywords)
    favorite_genre.append(keyword_occurences[0:5])
    
    name = "Cluster", (i + 1)
    makeCloud(keyword_occurences[0:5], name, "lemonchiffon")

# %%
def mean_reciprocal_rank(rs):
    rs = (np.asarray(r).nonzero()[0] for r in rs)
    return np.mean([1. / (r[0] + 1) if r.size else 0. for r in rs])

# %%
list_rank = list()
i = 0;
for i in range(best_k):
    cluster_x = cluster[i].sort_values(ascending = False)[0:15].index
    for j in movies_ratings[movies_ratings['cluster'] == i].index.values:
        list_user_rank = list()
        
        user_x = movies_ratings.loc[[j]]
        done = list(user_x.apply(lambda row: row[row == 1].index, axis = 1).values[0])
        recom_x = cluster[i][~cluster[i].index.isin(done) == True].sort_values(ascending = False)[0:15].index
        for k in range(len(cluster_x)):
            if cluster_x[k] == recom_x[k]:
                list_user_rank.append(1)
            else:
                list_user_rank.append(0)
                
        if j < 6 or j%10 == 0:
            print('userId:', j, '| MRR:', mean_reciprocal_rank(list_user_rank))
        list_rank.append(list_user_rank)
# Out:
# userId: 2 | MRR: 0.06666666666666667
# userId: 3 | MRR: 0.5333333333333333
# userId: 4 | MRR: 0.13333333333333333
# userId: 10 | MRR: 0.06666666666666667
# userId: 30 | MRR: 0.0
# userId: 40 | MRR: 0.0
# userId: 60 | MRR: 0.0
# userId: 70 | MRR: 0.0
# userId: 80 | MRR: 0.0
# userId: 90 | MRR: 0.5333333333333333
# userId: 100 | MRR: 0.06666666666666667
# userId: 110 | MRR: 0.13333333333333333
# userId: 120 | MRR: 0.5333333333333333
# userId: 130 | MRR: 0.0
# userId: 150 | MRR: 1.0
# userId: 170 | MRR: 0.0
# userId: 180 | MRR: 0.26666666666666666
# userId: 190 | MRR: 0.0
# userId: 210 | MRR: 0.13333333333333333
# userId: 230 | MRR: 0.0
# userId: 240 | MRR: 0.0
# userId: 250 | MRR: 0.13333333333333333
# userId: 260 | MRR: 0.2
# userId: 270 | MRR: 0.6666666666666666
# userId: 280 | MRR: 0.06666666666666667
# userId: 300 | MRR: 0.0
# userId: 310 | MRR: 0.8666666666666667
# userId: 320 | MRR: 0.7333333333333333
# userId: 340 | MRR: 0.0
# userId: 350 | MRR: 0.5333333333333333
# userId: 360 | MRR: 0.8666666666666667
# userId: 370 | MRR: 0.0
# userId: 390 | MRR: 0.26666666666666666
# userId: 400 | MRR: 0.0
# userId: 410 | MRR: 0.0
# userId: 420 | MRR: 0.0
# userId: 430 | MRR: 0.0
# userId: 440 | MRR: 0.8666666666666667
# userId: 450 | MRR: 0.3333333333333333
# userId: 460 | MRR: 0.0
# userId: 470 | MRR: 0.0
# userId: 490 | MRR: 0.06666666666666667
# userId: 500 | MRR: 0.06666666666666667
# userId: 510 | MRR: 0.2
# userId: 530 | MRR: 0.06666666666666667
# userId: 540 | MRR: 0.13333333333333333
# userId: 550 | MRR: 0.0
# userId: 380 | MRR: 0.0
# userId: 480 | MRR: 0.0
# userId: 590 | MRR: 0.0
# userId: 600 | MRR: 0.0
# userId: 610 | MRR: 0.0
# userId: 1 | MRR: 0.0
# userId: 20 | MRR: 0.6
# userId: 50 | MRR: 0.0
# userId: 140 | MRR: 0.0
# userId: 160 | MRR: 0.0
# userId: 200 | MRR: 0.0
# userId: 220 | MRR: 0.0
# userId: 290 | MRR: 0.13333333333333333
# userId: 330 | MRR: 0.0
# userId: 520 | MRR: 0.0
# userId: 560 | MRR: 0.0
# userId: 570 | MRR: 0.0
# userId: 580 | MRR: 0.0

# %%
def mean_reciprocal_rank(rs):
    rs = (np.asarray(r).nonzero()[0] for r in rs)
    return np.mean([1. / (r[0] + 1) if r.size else 0. for r in rs])

# %%
mean_reciprocal_rank(list_rank)
# Out:
# 0.44533417402269865

# %%
uid = 100
user_100 = movies_ratings.iloc[[uid - 1]]
user_clust = user_100['cluster'].values[0]
done = list(user_100.apply(lambda row: row[row == 1].index, axis = 1).values[0])
recom_100 = cluster[user_clust][~cluster[user_clust].index.isin(done) == True].sort_values(ascending = False)[0:15]
recom_100
# Out:
# title
# Shawshank Redemption, The (1994)             0.455487
# Silence of the Lambs, The (1991)             0.378882
# Matrix, The (1999)                           0.337474
# Braveheart (1995)                            0.320911
# Schindler's List (1993)                      0.304348
# Jurassic Park (1993)                         0.293996
# Star Wars: Episode IV - A New Hope (1977)    0.293996
# Apollo 13 (1995)                             0.285714
# Terminator 2: Judgment Day (1991)            0.279503
# Toy Story (1995)                             0.256729
# Usual Suspects, The (1995)                   0.248447
# Fugitive, The (1993)                         0.248447
# Fight Club (1999)                            0.246377
# Seven (a.k.a. Se7en) (1995)                  0.236025
# Independence Day (a.k.a. ID4) (1996)         0.231884
# dtype: float64

# %%
uid = 200
user_200 = movies_ratings.iloc[[uid - 1]]
user_clust = user_200['cluster'].values[0]
done = list(user_200.apply(lambda row: row[row == 1].index, axis = 1).values[0])
recom_200 = cluster[user_clust][~cluster[user_clust].index.isin(done) == True].sort_values(ascending = False)[0:15]
recom_200
# Out:
# title
# Saving Private Ryan (1998)                    0.747573
# Silence of the Lambs, The (1991)              0.737864
# Groundhog Day (1993)                          0.689320
# Sixth Sense, The (1999)                       0.689320
# Reservoir Dogs (1992)                         0.650485
# Fargo (1996)                                  0.650485
# Godfather, The (1972)                         0.650485
# Terminator 2: Judgment Day (1991)             0.640777
# Usual Suspects, The (1995)                    0.631068
# Monty Python and the Holy Grail (1975)        0.621359
# Terminator, The (1984)                        0.582524
# Ghostbusters (a.k.a. Ghost Busters) (1984)    0.572816
# Aliens (1986)                                 0.563107
# E.T. the Extra-Terrestrial (1982)             0.563107
# Clockwork Orange, A (1971)                    0.553398
# dtype: float64
